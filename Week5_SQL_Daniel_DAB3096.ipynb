# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeDJR/SQL-Murder-Mystery-Case/blob/main/Week5_SQL_Daniel_DAB3096.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **IMPORTNG PACKAGES**

# %%
import sqlite3
from prettytable import from_db_cursor

# %% [markdown]
# **DATABASE CONNECTION**

# %%
con = sqlite3.connect('/content/drive/MyDrive/5. Week 5 - SQL & Web Scrapping/sql-murder-mystery.db')

# %%
con

# %% [markdown]
# **CREATING A CURSOR TO EXECUTE THE QUERIES**

# %%
cur = con.cursor()

# %% [markdown]
# **FETCHING THE TABLES IN THE DATABASE**

# %%
cur.execute("SELECT name FROM sqlite_master WHERE type = 'table'")
pt = from_db_cursor(cur)
print(pt)
# Out:
# +------------------------+
# |          name          |
# +------------------------+
# |   crime_scene_report   |
# |    drivers_license     |
# |         person         |
# | facebook_event_checkin |
# |       interview        |
# |   get_fit_now_member   |
# |  get_fit_now_check_in  |
# |         income         |
# |        solution        |
# +------------------------+

# %% [markdown]
# **CHECKING THE STRUCTURE OF THE TABLES**

# %%
# CRIME SCENE REPORT TABLE
cur.execute("SELECT sql FROM sqlite_master WHERE name='crime_scene_report'")
pt=from_db_cursor(cur)
print(pt)
# Out:
# +-----------------------------------+
# |                sql                |
# +-----------------------------------+
# | CREATE TABLE crime_scene_report ( |
# |               date integer,       |
# |                 type text,        |
# |             description text,     |
# |                 city text         |
# |                   )               |
# +-----------------------------------+

# %%
# DRIVERS LICENSE TABLE
cur.execute("SELECT sql FROM sqlite_master WHERE name='drivers_license'")
pt=from_db_cursor(cur)
print(pt)
# Out:
# +---------------------------------+
# |               sql               |
# +---------------------------------+
# |  CREATE TABLE drivers_license ( |
# |         id integer PRIMARY KEY, |
# |               age integer,      |
# |             height integer,     |
# |             eye_color text,     |
# |             hair_color text,    |
# |               gender text,      |
# |            plate_number text,   |
# |              car_make text,     |
# |              car_model text     |
# |                  )              |
# +---------------------------------+

# %%
# PERSON TABLE
cur.execute("SELECT sql FROM sqlite_master WHERE name='person'")
pt=from_db_cursor(cur)
print(pt)
# Out:
# +-----------------------------------------------------------------+
# |                               sql                               |
# +-----------------------------------------------------------------+
# |                      CREATE TABLE person (                      |
# |                         id integer PRIMARY KEY,                 |
# |                                name text,                       |
# |                           license_id integer,                   |
# |                         address_number integer,                 |
# |                        address_street_name text,                |
# |                               ssn integer,                      |
# |         FOREIGN KEY (license_id) REFERENCES drivers_license(id) |
# |                                  )                              |
# +-----------------------------------------------------------------+

# %%
# FACEBOOK EVENT CHECK IN TABLE
cur.execute("SELECT sql FROM sqlite_master WHERE name='facebook_event_checkin'")
pt=from_db_cursor(cur)
print(pt)
# Out:
# +-------------------------------------------------------+
# |                          sql                          |
# +-------------------------------------------------------+
# |         CREATE TABLE facebook_event_checkin (         |
# |                       person_id integer,              |
# |                       event_id integer,               |
# |                        event_name text,               |
# |                         date integer,                 |
# |         FOREIGN KEY (person_id) REFERENCES person(id) |
# |                             )                         |
# +-------------------------------------------------------+

# %%
# INTERVIEW TABLE
cur.execute("SELECT sql FROM sqlite_master WHERE name='interview'")
pt=from_db_cursor(cur)
print(pt)
# Out:
# +-------------------------------------------------------+
# |                          sql                          |
# +-------------------------------------------------------+
# |                CREATE TABLE interview (               |
# |                       person_id integer,              |
# |                        transcript text,               |
# |         FOREIGN KEY (person_id) REFERENCES person(id) |
# |                             )                         |
# +-------------------------------------------------------+

# %%
# GET FIT NOW CHECK IN TABLE
cur.execute("SELECT sql FROM sqlite_master WHERE name='get_fit_now_check_in'")
pt=from_db_cursor(cur)
print(pt)
# Out:
# +-----------------------------------------------------------------------+
# |                                  sql                                  |
# +-----------------------------------------------------------------------+
# |                  CREATE TABLE get_fit_now_check_in (                  |
# |                              membership_id text,                      |
# |                             check_in_date integer,                    |
# |                             check_in_time integer,                    |
# |                            check_out_time integer,                    |
# |         FOREIGN KEY (membership_id) REFERENCES get_fit_now_member(id) |
# |                                     )                                 |
# +-----------------------------------------------------------------------+

# %%
# GET FIT NOW MEMBER TABLE
cur.execute("SELECT sql FROM sqlite_master WHERE name='get_fit_now_member'")
pt=from_db_cursor(cur)
print(pt)
# Out:
# +-------------------------------------------------------+
# |                          sql                          |
# +-------------------------------------------------------+
# |           CREATE TABLE get_fit_now_member (           |
# |                      id text PRIMARY KEY,             |
# |                       person_id integer,              |
# |                           name text,                  |
# |                 membership_start_date integer,        |
# |                    membership_status text,            |
# |         FOREIGN KEY (person_id) REFERENCES person(id) |
# |                             )                         |
# +-------------------------------------------------------+

# %%
# INCOME TABLE
cur.execute("SELECT sql FROM sqlite_master WHERE name='income'")
pt=from_db_cursor(cur)
print(pt)
# Out:
# +----------------------------------+
# |               sql                |
# +----------------------------------+
# |      CREATE TABLE income (       |
# |         ssn integer PRIMARY KEY, |
# |          annual_income integer   |
# |                  )               |
# +----------------------------------+

# %%
# SOLUTION
cur.execute("SELECT sql FROM sqlite_master WHERE name='solution'")
pt=from_db_cursor(cur)
print(pt)
# Out:
# +-------------------------+
# |           sql           |
# +-------------------------+
# | CREATE TABLE solution ( |
# |          user integer,  |
# |            value text   |
# |              )          |
# +-------------------------+

# %% [markdown]
# **FETCHING THE CRIME REPORT OF THE MURDER THAT WAS HAPPEND ON JAN-15-2018 IN SQL CITY**

# %%
cur.execute("SELECT * FROM crime_scene_report")
pt=from_db_cursor(cur)
print(pt)
# Out:
# +----------+-----------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------+
# |   date   |    type   |                                                                                        description                                                                                        |        city       |
# +----------+-----------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------+
# | 20180115 |  robbery  |                                                                     A Man Dressed as Spider-Man Is on a Robbery Spree                                                                     |        NYC        |
# ...

# %%
cur.execute("SELECT * FROM crime_scene_report WHERE date=20180115 AND type='murder' AND City='SQL City' ")
pt=from_db_cursor(cur)
print(pt)
# Out:
# +----------+--------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+
# |   date   |  type  |                                                                                        description                                                                                        |   city   |
# +----------+--------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+
# | 20180115 | murder | Security footage shows that there were 2 witnesses. The first witness lives at the last house on "Northwestern Dr". The second witness, named Annabel, lives somewhere on "Franklin Ave". | SQL City |
# ...

# %%
# TRACKING DOWN THE DETAILS OF THE WITNESSES
cur.execute("SELECT * FROM person WHERE address_street_name='Northwestern Dr' ORDER BY address_number ASC") # FIRST WITNESS
pt=from_db_cursor(cur)
print(pt)
# Out:
# +-------+----------------------+------------+----------------+---------------------+-----------+
# |   id  |         name         | license_id | address_number | address_street_name |    ssn    |
# +-------+----------------------+------------+----------------+---------------------+-----------+
# | 89906 |   Kinsey Erickson    |   510019   |      309       |   Northwestern Dr   | 635287661 |
# | 15171 |     Weldon Penso     |   336999   |      311       |   Northwestern Dr   | 131379495 |
# | 40336 |   Fredia Billeter    |   251082   |      404       |   Northwestern Dr   | 108056488 |
# | 85280 |      Donn Duin       |   569122   |      540       |   Northwestern Dr   | 613873810 |
# | 12711 |    Norman Apolito    |   667757   |      599       |   Northwestern Dr   | 778264744 |
# | 75484 |     Del Tacderen     |   447887   |      607       |   Northwestern Dr   | 243821337 |
# | 26758 |   Angelena Billman   |   942074   |      629       |   Northwestern Dr   | 341854756 |
# ...

# %%
# WITNESS 1 DETAILS:
# 14887	Morty Schapiro	118009	4919	Northwestern Dr	111564949

# %%
# NOW TRACKING DOWN THE SECOND WITNESS
cur.execute("select * FROM person where address_street_name = 'Franklin Ave' AND  name LIKE '%Annabel%'")
pt=from_db_cursor(cur)
print(pt)
# Out:
# +-------+----------------+------------+----------------+---------------------+-----------+
# |   id  |      name      | license_id | address_number | address_street_name |    ssn    |
# +-------+----------------+------------+----------------+---------------------+-----------+
# | 16371 | Annabel Miller |   490173   |      103       |     Franklin Ave    | 318771143 |
# +-------+----------------+------------+----------------+---------------------+-----------+

# %%
# WITNESS 2
# 16371 |    Annabel Miller   |   490173   |      103       |     Franklin Ave    | 318771143

# %%
# VIEWING THE INTERVIEWS OF 2 VITNESSES
cur.execute("SELECT * FROM interview WHERE person_id = 14887 OR person_id=16371" )
pt = from_db_cursor(cur)
print(pt)
# Out:
# +-----------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | person_id |                                                                                                            transcript                                                                                                           |
# +-----------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   14887   | I heard a gunshot and then saw a man run out. He had a "Get Fit Now Gym" bag. The membership number on the bag started with "48Z". Only gold members have those bags. The man got into a car with a plate that included "H42W". |
# ...

# %%
# NOW CHECKING THE GYM MEMBERSHIP WITH GOLD MEMBERSHIP
cur.execute("SELECT * FROM get_fit_now_member WHERE membership_status = 'gold' AND id LIKE '%48Z%'")
pt=from_db_cursor(cur)
print(pt)
# Out:
# +-------+-----------+---------------+-----------------------+-------------------+
# |   id  | person_id |      name     | membership_start_date | membership_status |
# +-------+-----------+---------------+-----------------------+-------------------+
# | 48Z7A |   28819   |  Joe Germuska |        20160305       |        gold       |
# | 48Z55 |   67318   | Jeremy Bowers |        20160101       |        gold       |
# +-------+-----------+---------------+-----------------------+-------------------+

# %%
# WE HAVE FOUND TWO SUSPECTS

# %%
# CHECKING THEIR CHECKIN DETAILS
cur.execute("SELECT * FROM get_fit_now_check_in WHERE membership_id = '48Z7A' or membership_id = '48Z55'")
pt=from_db_cursor(cur)
print(pt)
# Out:
# +---------------+---------------+---------------+----------------+
# | membership_id | check_in_date | check_in_time | check_out_time |
# +---------------+---------------+---------------+----------------+
# |     48Z7A     |    20180109   |      1600     |      1730      |
# |     48Z55     |    20180109   |      1530     |      1700      |
# +---------------+---------------+---------------+----------------+

# %%
# BOTH THE SUSPECTS WHERE VISITED THE GYM LAST WEEK ON THE SAME DATE MENTIONED BY WITNESS 2 IN HER INTERVIEW SESSION.

# %%
cur.execute("SELECT * FROM get_fit_now_check_in WHERE membership_id = '48Z7A' or membership_id = '48Z55' OR check_in_date = 20180115")
pt=from_db_cursor(cur)
print(pt)
# Out:
# +---------------+---------------+---------------+----------------+
# | membership_id | check_in_date | check_in_time | check_out_time |
# +---------------+---------------+---------------+----------------+
# |     D2KY6     |    20180115   |      746      |      836       |
# |     344VM     |    20180115   |      1087     |      1195      |
# |     3BRSC     |    20180115   |      354      |      825       |
# |     HM6U8     |    20180115   |      525      |      800       |
# |     48Z7A     |    20180109   |      1600     |      1730      |
# |     48Z55     |    20180109   |      1530     |      1700      |
# +---------------+---------------+---------------+----------------+

# %%
# NOW WE KNOW THAT BOTH THE SUSPECTS VISITED THE GYM LAST WEEK AND ALSO NOT VISITED THE GYM ON THE DAY THAT MURDER HAPPENED.

# %% [markdown]
# **NOW TRACING THE CAR NUMBER PLATE**

# %%
# FIRST WE NEED TO GET THE PERSON ID OF BOTH THE SUSPECTS
cur.execute("SELECT * FROM get_fit_now_member WHERE id = '48Z7A' OR id = '48Z55'")
pt = from_db_cursor(cur)
print(pt)
# Out:
# +-------+-----------+---------------+-----------------------+-------------------+
# |   id  | person_id |      name     | membership_start_date | membership_status |
# +-------+-----------+---------------+-----------------------+-------------------+
# | 48Z55 |   67318   | Jeremy Bowers |        20160101       |        gold       |
# | 48Z7A |   28819   |  Joe Germuska |        20160305       |        gold       |
# +-------+-----------+---------------+-----------------------+-------------------+

# %%
# NOW TRACING THE LICENSE ID OF THE TWO SUSPECTS USNG THEIR PERSON IDs
cur.execute("SELECT * FROM person WHERE id = 67318 OR id = 28819")
pt = from_db_cursor(cur)
print(pt)
# Out:
# +-------+---------------+------------+----------------+-----------------------+-----------+
# |   id  |      name     | license_id | address_number |  address_street_name  |    ssn    |
# +-------+---------------+------------+----------------+-----------------------+-----------+
# | 28819 |  Joe Germuska |   173289   |      111       |        Fisk Rd        | 138909730 |
# | 67318 | Jeremy Bowers |   423327   |      530       | Washington Pl, Apt 3A | 871539279 |
# +-------+---------------+------------+----------------+-----------------------+-----------+

# %%
# NOW TRACING DOWN THE NUMBER PLATES OF BOTH THE SUSPECT
cur.execute("SELECT name, license_id, plate_number FROM person INNER JOIN drivers_license ON person.license_id = drivers_license.id WHERE license_id =  173289 or license_id = 423327")
pt = from_db_cursor(cur)
print(pt)
# Out:
# +---------------+------------+--------------+
# |      name     | license_id | plate_number |
# +---------------+------------+--------------+
# | Jeremy Bowers |   423327   |    0H42W2    |
# +---------------+------------+--------------+

# %%
# Jeremy Bowers is the Murderer.

# %% [markdown]
# **TAKING A LOOK ON MURDERER'S INTERVIEW**

# %%
cur.execute("SELECT * FROM interview WHERE person_id = 67318")
pt = from_db_cursor(cur)
pt
# Out:
# +-----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | person_id |                                                                                                                    transcript                                                                                                                    |
# +-----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# ...

# %%
# THE MURDERER HAS MADE A CONFESSION ABOUT HIS HIRER WHO HIRED HIM FOR THE MURDER.
# LET'S FIND THE MASTER MIND BEHIND THIS

# %%
cur.execute("SELECT * FROM drivers_license WHERE gender = 'female' AND hair_color = 'red' AND car_make = 'Tesla' AND car_model = 'Model S'")
pt = from_db_cursor(cur)
pt
# Out:
# +--------+-----+--------+-----------+------------+--------+--------------+----------+-----------+
# |   id   | age | height | eye_color | hair_color | gender | plate_number | car_make | car_model |
# +--------+-----+--------+-----------+------------+--------+--------------+----------+-----------+
# | 202298 |  68 |   66   |   green   |    red     | female |    500123    |  Tesla   |  Model S  |
# | 291182 |  65 |   66   |    blue   |    red     | female |    08CM64    |  Tesla   |  Model S  |
# | 918773 |  48 |   65   |   black   |    red     | female |    917UU3    |  Tesla   |  Model S  |
# +--------+-----+--------+-----------+------------+--------+--------------+----------+-----------+

# %%
# FINDING PERSON IDs FOR THE SUSPECTS ABOVE
cur. execute("select * from person WHERE license_id = 202298 OR license_id = 291182 OR license_id = 918773 ")
pt = from_db_cursor(cur)
print(pt)
# Out:
# +-------+------------------+------------+----------------+---------------------+-----------+
# |   id  |       name       | license_id | address_number | address_street_name |    ssn    |
# +-------+------------------+------------+----------------+---------------------+-----------+
# | 78881 |     Red Korb     |   918773   |      107       |     Camerata Dr     | 961388910 |
# | 90700 |  Regina George   |   291182   |      332       |      Maple Ave      | 337169072 |
# | 99716 | Miranda Priestly |   202298   |      1883      |      Golden Ave     | 987756388 |
# +-------+------------------+------------+----------------+---------------------+-----------+

# %%
# CHECKING THEIR CONFESSION FROM THEIR INTERVIEW SESSION
cur. execute("select * from interview WHERE person_id = 78881 OR person_id = 90700 OR person_id = 99716  ")
pt = from_db_cursor(cur)
print(pt)
# Out:
# +-----------+------------+
# | person_id | transcript |
# +-----------+------------+
# +-----------+------------+

# %%
# NO RECORD ON THEM IN THE INTERVIEW TABLE

# %%
# WE KNOW THAT THE MURDER TOLD US SOMETHING ABOUT THE EVENT THAT THE BENEFACTOR WAS ATTENDING ABOUT. SO LET'S LOOK INTO IT.
cur. execute("select person_id, name, event_name, date, count(*) from facebook_event_checkin INNER JOIN person ON facebook_event_checkin.person_id = person.id GROuP BY person_id HAVING date LIKE '%201712%' AND event_name = 'SQL Symphony Concert'")
pt = from_db_cursor(cur)
print(pt)
# Out:
# +-----------+------------------+----------------------+----------+----------+
# | person_id |       name       |      event_name      |   date   | count(*) |
# +-----------+------------------+----------------------+----------+----------+
# |   24556   |   Bryan Pardo    | SQL Symphony Concert | 20171207 |    3     |
# |   69325   |   Tyson Ojard    | SQL Symphony Concert | 20171206 |    1     |
# |   81526   |   Odis Manteca   | SQL Symphony Concert | 20171202 |    1     |
# |   99716   | Miranda Priestly | SQL Symphony Concert | 20171206 |    3     |
# +-----------+------------------+----------------------+----------+----------+

# %% [markdown]
# **CONCLUSION**
#
# 1.   'Jeremy Bowers' is the murderer
# 2.   'Miranda Priestly' is the Benefactor who hired the murderer
